# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
folder_path = 'Data\hangmu.csv'
raw_df = pd.read_csv(folder_path)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1612 entries, 0 to 1611
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        1612 non-null   int64
#  1   text                           1464 non-null   object
#  2   post_text                      1464 non-null   object
#  3   shared_text                    9 non-null      object
#  4   original_text                  0 non-null      float64
#  5   time                           1612 non-null   object
#  6   timestamp                      1612 non-null   int64
#  7   image                          1181 non-null   object
#  8   image_lowquality               1515 non-null   object
#  9   images                         1612 non-null   object
#  10  images_description             1612 non-null   object
#  11  images_lowquality              1612 non-null   object
#  12  images_lowquality_description  1612 non-null   object
#  13  video                          339 non-null    object
#  14  video_duration_seconds         0 non-null      float64
#  15  video_height                   0 non-null      float64
#  16  video_id                       339 non-null    float64
#  17  video_quality                  0 non-null      float64
#  18  video_size_MB                  0 non-null      float64
#  19  video_thumbnail                322 non-null    object
#  20  video_watches                  0 non-null      float64
#  21  video_width                    0 non-null      float64
#  22  likes                          1612 non-null   int64
#  23  comments                       1612 non-null   int64
#  24  shares                         1612 non-null   int64
#  25  post_url                       1611 non-null   object
#  26  link                           3 non-null      object
#  27  links                          1600 non-null   object
#  28  user_id                        1612 non-null   int64
#  29  username                       1612 non-null   object
#  30  user_url                       81 non-null     object
#  31  is_live                        1612 non-null   bool
#  32  factcheck                      0 non-null      float64
#  33  shared_post_id                 11 non-null     float64
#  34  shared_time                    11 non-null     object
#  35  shared_user_id                 11 non-null     float64
#  36  shared_username                11 non-null     object
#  37  shared_post_url                11 non-null     object
#  38  available                      1612 non-null   bool
#  39  comments_full                  1612 non-null   object
#  40  reactors                       0 non-null      float64
#  41  w3_fb_url                      0 non-null      float64
#  42  reactions                      0 non-null      float64
#  43  reaction_count                 1612 non-null   int64
#  44  with                           1523 non-null   object
#  45  page_id                        284 non-null    float64
#  46  sharers                        0 non-null      float64
#  47  image_id                       1014 non-null   float64
#  48  image_ids                      1612 non-null   object
#  49  was_live                       1612 non-null   bool
#  50  header                         1523 non-null   object
# dtypes: bool(3), float64(17), int64(7), object(24)
# memory usage: 609.4+ KB

# %% [markdown]
# # **Feature removal**

# %%
drop_column_list = ['post_text', 'timestamp', 'images_lowquality_description', 'shared_post_id', 'shared_user_id', 'shared_username', 'shared_post_url', 'image_id', 'image_ids', 'image', 
                     'image_lowquality', 'images', 'images_lowquality', 'video', 'video_thumbnail', 'post_url', 'link', 'links', 'user_url', 'original_text', 
                     'video_duration_seconds', 'video_height', 'video_quality', 'video_size_MB', 'video_watches', 'video_width', 'factcheck', 'reactors', 
                     'w3_fb_url', 'reactions', 'sharers', 'shared_time']

# %%
raw_df.drop(drop_column_list, axis= 1, inplace= True)

# %%
raw_df.shape
# Out:
# (1612, 19)

# %% [markdown]
# # **Remove duplicates**

# %%
raw_df.drop_duplicates(subset= 'post_id', inplace= True)

# %%
raw_df.head()
# Out:
#             post_id                                               text  \
# 0  1432619150570316                 Tất cả anh em trong hang chú ý!!!!
# 1  1709707086194853                          1 năm rồi đấy, nhanh thật
# 2  1707877613044467  Trong hang chán quá nên nghịch 1 tí 🤣 Chờ ngày...
# 3  1710030909495804                                  Ảo Malaysia :))))
# 4  1709810706184491  1. David Moyse: tạt tạt tạt tạt => không bài v...
#
#   shared_text                 time  \
# 0         NaN  2022-09-05 00:36:39
# 1         NaN  2023-11-13 22:32:37
# 2         NaN  2023-11-10 18:58:31
# 3         NaN  2023-11-14 14:58:43
# 4         NaN  2023-11-14 03:16:23
#
#                                   images_description      video_id  likes  \
# 0                                                 []  7.748442e+14    728
# 1  ['Có thể là hình ảnh về 2 người, bộ vét và tro...           NaN    360
# 2                                                 []  1.002498e+15    481
# 3  ["Có thể là hình ảnh về 6 người, mọi người đan...           NaN     65
# 4  ['Có thể là hình ảnh về 1 người, đang chơi bón...           NaN    170
#
#    comments  shares          user_id           username  is_live  available  \
# 0       134       0  100016993770190     Nguyễn Bát Man    False       True
# 1        26       0  100005247039084         Thinh Pham    False       True
# 2        25       0  100089869466307        Văn Hùng Hà    False       True
# 3         9       0  100012623049308  Nguyễn Đào Nguyên    False       True
# 4        24       0  358460312962600            Hang MU    False       True
#
#   comments_full  reaction_count  \
# 0            []             728
# 1            []             360
# 2            []             481
# 3            []              65
# 4            []             170
#
#                                                 with       page_id  was_live  \
# 0  [{'name': 'Hang MU', 'link': 'https://m.facebo...  1.076085e+14     False
# 1  [{'name': 'Hang MU', 'link': 'https://m.facebo...           NaN     False
# 2  [{'name': 'Hang MU', 'link': 'https://m.facebo...           NaN     False
# 3  [{'name': 'Hang MU', 'link': 'https://m.facebo...           NaN     False
# 4                                                NaN           NaN     False
#
#                       header
# 0     Nguyễn Bát Man‎Hang MU
# 1         Thinh Pham‎Hang MU
# 2        Văn Hùng Hà‎Hang MU
# 3  Nguyễn Đào Nguyên‎Hang MU
# 4                        NaN

# %%
raw_df.reset_index(inplace= True, drop= True)
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1535 entries, 0 to 1534
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   post_id             1535 non-null   int64
#  1   text                1387 non-null   object
#  2   shared_text         9 non-null      object
#  3   time                1535 non-null   object
#  4   images_description  1535 non-null   object
#  5   video_id            262 non-null    float64
#  6   likes               1535 non-null   int64
#  7   comments            1535 non-null   int64
#  8   shares              1535 non-null   int64
#  9   user_id             1535 non-null   int64
#  10  username            1535 non-null   object
#  11  is_live             1535 non-null   bool
#  12  available           1535 non-null   bool
#  13  comments_full       1535 non-null   object
#  14  reaction_count      1535 non-null   int64
#  15  with                1446 non-null   object
#  16  page_id             207 non-null    float64
#  17  was_live            1535 non-null   bool
#  18  header              1446 non-null   object
# dtypes: bool(3), float64(2), int64(6), object(8)
# memory usage: 196.5+ KB

# %% [markdown]
# # **Remove data before 2022**

# %%
type(raw_df['time'].loc[0])
raw_df['time'].loc[0]
# Out:
# '2022-09-05 00:36:39'

# %%
raw_df['time'] = pd.to_datetime(raw_df['time'])

# %%
df = raw_df.loc[raw_df['time'] >= pd.to_datetime('2022-01-01')]

# %%
df.shape
# Out:
# (1529, 19)

# %% [markdown]
# ## **Handling missing data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1529 entries, 0 to 1533
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   post_id             1529 non-null   int64
#  1   text                1381 non-null   object
#  2   shared_text         9 non-null      object
#  3   time                1529 non-null   datetime64[ns]
#  4   images_description  1529 non-null   object
#  5   video_id            261 non-null    float64
#  6   likes               1529 non-null   int64
#  7   comments            1529 non-null   int64
#  8   shares              1529 non-null   int64
#  9   user_id             1529 non-null   int64
#  10  username            1529 non-null   object
#  11  is_live             1529 non-null   bool
#  12  available           1529 non-null   bool
#  13  comments_full       1529 non-null   object
#  14  reaction_count      1529 non-null   int64
#  15  with                1440 non-null   object
#  16  page_id             206 non-null    float64
#  17  was_live            1529 non-null   bool
#  18  header              1440 non-null   object
# dtypes: bool(3), datetime64[ns](1), float64(2), int64(6), object(7)
# memory usage: 207.5+ KB

# %%
df.fillna({'text': ' ', 'shared_text': ' ', }, inplace= True)
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_13556\3901552196.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna({'text': ' ', 'shared_text': ' ', }, inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1529 entries, 0 to 1533
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   post_id             1529 non-null   int64
#  1   text                1529 non-null   object
#  2   shared_text         1529 non-null   object
#  3   time                1529 non-null   datetime64[ns]
#  4   images_description  1529 non-null   object
#  5   video_id            261 non-null    float64
#  6   likes               1529 non-null   int64
#  7   comments            1529 non-null   int64
#  8   shares              1529 non-null   int64
#  9   user_id             1529 non-null   int64
#  10  username            1529 non-null   object
#  11  is_live             1529 non-null   bool
#  12  available           1529 non-null   bool
#  13  comments_full       1529 non-null   object
#  14  reaction_count      1529 non-null   int64
#  15  with                1440 non-null   object
#  16  page_id             206 non-null    float64
#  17  was_live            1529 non-null   bool
#  18  header              1440 non-null   object
# dtypes: bool(3), datetime64[ns](1), float64(2), int64(6), object(7)
# memory usage: 207.5+ KB

# %% [markdown]
# # **Save cleaned data**

# %%
# raw_df.loc[raw_df['comments_full'].str.len() != 0]

# %%
df
# Out:
#                post_id                                               text  \
# 0     1432619150570316                 Tất cả anh em trong hang chú ý!!!!
# 1     1709707086194853                          1 năm rồi đấy, nhanh thật
# 2     1707877613044467  Trong hang chán quá nên nghịch 1 tí 🤣 Chờ ngày...
# 3     1710030909495804                                  Ảo Malaysia :))))
# 4     1709810706184491  1. David Moyse: tạt tạt tạt tạt => không bài v...
# ...                ...                                                ...
# 1529  1657251314773764  Góc nhờ vả… mình bên hàn muốn mua cái áo này n...
# 1530  1659036177928611  các ông nhận định 4 vs 5-0 lm gì ?? xem mà thó...
# 1531  1658995144599381                              2h nhé các bác ơi 😍😘🥰
# 1532  1657241518108077  GỖ khó mà trở lại ngay bây giờ rồi. Chắc còn l...
# 1533  1659060107926218                                      Cu Chong à ae
#
#      shared_text                time  \
# 0                2022-09-05 00:36:39
# 1                2023-11-13 22:32:37
# 2                2023-11-10 18:58:31
# 3                2023-11-14 14:58:43
# 4                2023-11-14 03:16:23
# ...          ...                 ...
# 1529             2023-08-11 21:34:52
# 1530             2023-08-15 02:52:08
# 1531             2023-08-15 01:01:46
# 1532             2023-08-11 21:15:05
# 1533             2023-08-15 04:00:56
#
#                                      images_description      video_id  likes  \
# 0                                                    []  7.748442e+14    728
# 1     ['Có thể là hình ảnh về 2 người, bộ vét và tro...           NaN    360
# 2                                                    []  1.002498e+15    481
# 3     ["Có thể là hình ảnh về 6 người, mọi người đan...           NaN     65
# 4     ['Có thể là hình ảnh về 1 người, đang chơi bón...           NaN    170
# ...                                                 ...           ...    ...
# 1529                            ['Không có mô tả ảnh.']           NaN    625
# 1530                                                 []           NaN    162
# 1531                            ['Không có mô tả ảnh.']           NaN    424
# 1532                            ['Không có mô tả ảnh.']           NaN    227
# 1533                            ['Không có mô tả ảnh.']           NaN     92
#
#       comments  shares          user_id           username  is_live  \
# 0          134       0  100016993770190     Nguyễn Bát Man    False
# 1           26       0  100005247039084         Thinh Pham    False
# 2           25       0  100089869466307        Văn Hùng Hà    False
# 3            9       0  100012623049308  Nguyễn Đào Nguyên    False
# 4           24       0  358460312962600            Hang MU    False
# ...        ...     ...              ...                ...      ...
# 1529        36       0  100091601216404       Lê Văn Cường    False
# 1530        56       0  100036355747178       Ngô Hải Long    False
# 1531        42       0  100046564666491          Người Thỏ    False
# 1532        19       0  100079920938177        Fish Winged    False
# 1533         2       0  100054979685294         Tuấn Nghĩa    False
#
#       available comments_full  reaction_count  \
# 0          True            []             728
# 1          True            []             360
# 2          True            []             481
# 3          True            []              65
# 4          True            []             170
# ...         ...           ...             ...
# 1529       True            []             625
# 1530       True            []             162
# 1531       True            []             424
# 1532       True            []             227
# 1533       True            []              92
#
#                                                    with       page_id  \
# 0     [{'name': 'Hang MU', 'link': 'https://m.facebo...  1.076085e+14
# 1     [{'name': 'Hang MU', 'link': 'https://m.facebo...           NaN
# 2     [{'name': 'Hang MU', 'link': 'https://m.facebo...           NaN
# 3     [{'name': 'Hang MU', 'link': 'https://m.facebo...           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 1529  [{'name': 'Hang MU', 'link': 'https://m.facebo...           NaN
# 1530  [{'name': 'Hang MU', 'link': 'https://m.facebo...           NaN
# 1531  [{'name': 'Hang MU', 'link': 'https://m.facebo...           NaN
# 1532  [{'name': 'Hang MU', 'link': 'https://m.facebo...           NaN
# 1533  [{'name': 'Hang MU', 'link': 'https://m.facebo...           NaN
#
#       was_live                     header
# 0        False     Nguyễn Bát Man‎Hang MU
# 1        False         Thinh Pham‎Hang MU
# 2        False        Văn Hùng Hà‎Hang MU
# 3        False  Nguyễn Đào Nguyên‎Hang MU
# 4        False                        NaN
# ...        ...                        ...
# 1529     False       Lê Văn Cường‎Hang MU
# 1530     False       Ngô Hải Long‎Hang MU
# 1531     False          Người Thỏ‎Hang MU
# 1532     False        Fish Winged‎Hang MU
# 1533     False         Tuấn Nghĩa‎Hang MU
#
# [1529 rows x 19 columns]

# %%
n = folder_path.rfind('\\')
path = folder_path[:n+ 1] + 'cleaned_' + folder_path[n + 1:]
df.to_csv(path, index=False)
print(path)
# Out:
# Data\cleaned_hangmu.csv
